# %%
# initial imports
import pandas as pd
from pathlib import Path

# %%
#set file path
file_path = Path("C:/Users/gerar/OneDrive/Desktop/home_test/limit_data.csv")
# create dataframe
df = pd.read_csv(file_path)

# %%
# checking file
df.head(5)
# Out:
#   Strategy Product  Internal Limit in coin Product.1 Currency     Price  \
# 0       S4     ZIL              366020.000       ICP      USD  4.950000
# 1       S4     BTC                   2.835       SRM      USD  0.717000
# 2       S4    USDT              139315.340       ICX      USD  0.214200
# 3       S4    BUSD              107574.305       XLM      USD  0.112900
# 4       S4     XRP               87968.500       BTT      USD  0.002777
#
#       Instrument  Coin  Exchange position limit notional ( in BTC)  \
# 0   ZIL_exchange   ZIL                                        1.56
# 1   BTC_exchange   BTC                                        0.52
# 2  USDT_exchange  USDT                                        0.21
# 3  BUSD_exchange  BUSD                                        0.52
# 4   XRP_exchange   XRP                                        1.04
#
#   Portfolio Limit (in USD)  Limit Per Individual Product (in USD)
# 0               1,600,000                                  75,000
# 1                      NaN                                    NaN
# 2                      NaN                                    NaN
# 3                      NaN                                    NaN
# 4                      NaN                                    NaN

# %%
# create new df for product and internal limit in coin (the first tables in the excel sheet)

internal_df = df[['Product','Internal Limit in coin']].copy()

# %%
#Check ( we didnt include the strategy column since its not needed)
internal_df.head()
# Out:
#   Product  Internal Limit in coin
# 0     ZIL              366020.000
# 1     BTC                   2.835
# 2    USDT              139315.340
# 3    BUSD              107574.305
# 4     XRP               87968.500

# %%
# create new df for prices ( second table in excel sheet)
price_df = df[['Product.1','Price']].copy()

# %%
#check
price_df.head()
# Out:
#   Product.1     Price
# 0       ICP  4.950000
# 1       SRM  0.717000
# 2       ICX  0.214200
# 3       XLM  0.112900
# 4       BTT  0.002777

# %%
# Rename Column in order to create merge (we need a column named identically in order to do merge /vlookup)
price_df = price_df.rename(columns={'Product.1': 'Product'})

# %%
#check
price_df
# Out:
#     Product         Price
# 0       ICP      4.950000
# 1       SRM      0.717000
# 2       ICX      0.214200
# 3       XLM      0.112900
# 4       BTT      0.002777
# ..      ...           ...
# 357    HIGH      1.401000
# 358    MOVR      9.930000
# 359    GLMR      0.430800
# 360    BETH   1272.517239
# 361     BTC  19176.690000
#
# [362 rows x 2 columns]

# %%
#create inner join merge , equivalent of VLOOKUP
inner_join = pd.merge(internal_df, price_df, on ='Product', how ='inner')

# %%
#check
inner_join
# Out:
#    Product  Internal Limit in coin        Price
# 0      ZIL              366020.000      0.03000
# 1      BTC                   2.835  19176.69000
# 2      BTC                   1.200  19176.69000
# 3      BTC                   1.655  19176.69000
# 4      BTC                   0.895  19176.69000
# ..     ...                     ...          ...
# 71    COTI               73126.500      0.09680
# 72     CLV              109648.500      0.09795
# 73     CHR               63457.500      0.13950
# 74    API3                2874.000      1.52500
# 75     XLM              110886.500      0.11290
#
# [76 rows x 3 columns]

# %%
#create new column by obtaining the product (*) of "price" and "internal limit in coin"
inner_join['USD Value'] = inner_join['Internal Limit in coin'] * inner_join ['Price']

# %%
#check - now we had a USD Value for all internal coins.
inner_join.head(30)
# Out:
#    Product  Internal Limit in coin        Price      USD Value
# 0      ZIL              366020.000      0.03000   10980.600000
# 1      BTC                   2.835  19176.69000   54365.916150
# 2      BTC                   1.200  19176.69000   23012.028000
# 3      BTC                   1.655  19176.69000   31737.421950
# 4      BTC                   0.895  19176.69000   17163.137550
# 5      BTC                   1.235  19176.69000   23683.212150
# 6     USDT              139315.340      1.00000  139315.340000
# 7     USDT               91589.225      1.00000   91589.225000
# 8     USDT               70516.560      1.00000   70516.560000
# 9     USDT               81770.505      1.00000   81770.505000
# 10    USDT               92460.150      1.00000   92460.150000
# 11    BUSD              107574.305      1.00010  107585.062430
# 12    BUSD               58843.260      1.00010   58849.144326
# 13    BUSD               84296.495      1.00010   84304.924649
# 14    BUSD               63858.775      1.00010   63865.160877
# 15    BUSD               53830.600      1.00010   53835.983060
# 16     XRP               87968.500      0.29700   26126.644500
# 17   THETA                8973.000      0.99200    8901.216000
# 18    RNDR               27288.000      0.40000   10915.200000
# 19    REEF             1264168.000      0.00610    7711.424800
# 20   QUICK                 137.500     57.70000    7933.750000
# 21    LINK                2799.500      6.89270   19296.113650
# 22    LINA             1382752.000      0.00705    9748.401600
# 23    GALA              431126.000      0.03660   15779.211600
# 24    DOGE              437672.500      0.05860   25647.608500
# 25    COMP                 162.500     54.11000    8792.875000
# 26    CAKE                2542.500      4.40900   11209.882500
# 27    BOND                2512.000      4.57000   11479.840000
# 28     BLZ               86689.500      0.07540    6536.388300
# 29    BAKE               61669.500      0.21780   13431.617100

# %%
#create pivot table aggregating by product - we are adding all the values.
pivot_table = pd.pivot_table(inner_join, values='USD Value', index='Product', aggfunc='sum')

pivot_table.head(20)
# Out:
#              USD Value
# Product
# ADA       28333.649450
# ALGO      13869.384000
# API3       4382.850000
# AUDIO     10665.625500
# AVAX      22366.540000
# BAKE      13431.617100
# BLZ        6536.388300
# BOND      11479.840000
# BSW        6558.675000
# BTC      149961.715800
# BURGER     8894.480000
# BUSD     368440.275344
# C98       12478.782000
# CAKE      11209.882500
# CHR        8852.321250
# CLV       10740.070575
# COMP       8792.875000
# COTI       7078.645200
# DEXE       6035.830500
# DOGE      25647.608500

# %%
#this is the total internal value in USD
pivot_table['USD Value'].sum()
# Out:
# 1770395.4349250547

# %%
# Are we within our internal overall portfolio limit ? - Yes we are over by roughly 170 k.
(1770395.43 - 1600000)
# Out:
# 170395.42999999993

# %%
exchange = df[['Instrument','Coin','Exchange position limit notional ( in BTC)']].copy()

# %%
#check
exchange.head(20)
# Out:
#         Instrument   Coin  Exchange position limit notional ( in BTC)
# 0     ZIL_exchange    ZIL                                        1.56
# 1     BTC_exchange    BTC                                        0.52
# 2    USDT_exchange   USDT                                        0.21
# 3    BUSD_exchange   BUSD                                        0.52
# 4     XRP_exchange    XRP                                        1.04
# 5   THETA_exchange  THETA                                        0.52
# 6    RNDR_exchange   RNDR                                        0.52
# 7    REEF_exchange   REEF                                        0.52
# 8   QUICK_exchange  QUICK                                        0.52
# 9    LINK_exchange   LINK                                        7.82
# 10   LINA_exchange   LINA                                        0.52
# 11   GALA_exchange   GALA                                       19.29
# 12   DOGE_exchange   DOGE                                        0.52
# 13   COMP_exchange   COMP                                        0.52
# 14   CAKE_exchange   CAKE                                        0.52
# 15   BOND_exchange   BOND                                        0.52
# 16    BLZ_exchange    BLZ                                        0.52
# 17   BAKE_exchange   BAKE                                        0.52
# 18   AVAX_exchange   AVAX                                        0.52
# 19  AUDIO_exchange  AUDIO                                        1.56

# %%
# create new column to display USD Value by multiplying BTC price given.
exchange['USD Value'] = df['Exchange position limit notional ( in BTC)'] * 19176.69

# %%
#check
exchange
# Out:
#         Instrument  Coin  Exchange position limit notional ( in BTC)  \
# 0     ZIL_exchange   ZIL                                        1.56
# 1     BTC_exchange   BTC                                        0.52
# 2    USDT_exchange  USDT                                        0.21
# 3    BUSD_exchange  BUSD                                        0.52
# 4     XRP_exchange   XRP                                        1.04
# ..             ...   ...                                         ...
# 357            NaN   NaN                                         NaN
# 358            NaN   NaN                                         NaN
# 359            NaN   NaN                                         NaN
# 360            NaN   NaN                                         NaN
# 361            NaN   NaN                                         NaN
#
#       USD Value
# 0    29915.6364
# 1     9971.8788
# 2     4027.1049
# 3     9971.8788
# 4    19943.7576
# ..          ...
# 357         NaN
# 358         NaN
# 359         NaN
# 360         NaN
# 361         NaN
#
# [362 rows x 4 columns]

# %%
#drop nulls
exchange.dropna(inplace=True)

# %%
#check
exchange
# Out:
#        Instrument  Coin  Exchange position limit notional ( in BTC)  \
# 0    ZIL_exchange   ZIL                                        1.56
# 1    BTC_exchange   BTC                                        0.52
# 2   USDT_exchange  USDT                                        0.21
# 3   BUSD_exchange  BUSD                                        0.52
# 4    XRP_exchange   XRP                                        1.04
# ..            ...   ...                                         ...
# 59  COTI_exchange  COTI                                        1.56
# 60   CLV_exchange   CLV                                        0.52
# 61   CHR_exchange   CHR                                        0.52
# 62  API3_exchange  API3                                        0.52
# 63   XLM_exchange   XLM                                        0.52
#
#      USD Value
# 0   29915.6364
# 1    9971.8788
# 2    4027.1049
# 3    9971.8788
# 4   19943.7576
# ..         ...
# 59  29915.6364
# 60   9971.8788
# 61   9971.8788
# 62   9971.8788
# 63   9971.8788
#
# [64 rows x 4 columns]

# %%
#Sorting by Coin
exchange.sort_values(by=['Coin'],inplace=True)

# %%
exchange
# Out:
#         Instrument   Coin  Exchange position limit notional ( in BTC)  \
# 21    ADA_exchange    ADA                                        0.52
# 20   ALGO_exchange   ALGO                                        1.56
# 62   API3_exchange   API3                                        0.52
# 19  AUDIO_exchange  AUDIO                                        1.56
# 18   AVAX_exchange   AVAX                                        0.52
# ..             ...    ...                                         ...
# 4     XRP_exchange    XRP                                        1.04
# 23    XTZ_exchange    XTZ                                        2.09
# 36    YGG_exchange    YGG                                        1.04
# 22    ZEC_exchange    ZEC                                        0.52
# 0     ZIL_exchange    ZIL                                        1.56
#
#      USD Value
# 21   9971.8788
# 20  29915.6364
# 62   9971.8788
# 19  29915.6364
# 18   9971.8788
# ..         ...
# 4   19943.7576
# 23  40079.2821
# 36  19943.7576
# 22   9971.8788
# 0   29915.6364
#
# [64 rows x 4 columns]

# %%
# second pivot table summarizes Coin and USD Value for the Exchange.

pivot_table_exchange = pd.pivot_table(exchange, values='USD Value', index='Coin', aggfunc='sum')

pivot_table_exchange.head(20)
# Out:
#          USD Value
# Coin
# ADA      9971.8788
# ALGO    29915.6364
# API3     9971.8788
# AUDIO   29915.6364
# AVAX     9971.8788
# BAKE     9971.8788
# BLZ      9971.8788
# BOND     9971.8788
# BSW      9971.8788
# BTC      9971.8788
# BURGER   9971.8788
# BUSD     9971.8788
# C98      3068.2704
# CAKE     9971.8788
# CHR      9971.8788
# CLV      9971.8788
# COMP     9971.8788
# COTI    29915.6364
# DEXE    19943.7576
# DOGE     9971.8788

# %%
#Pseudocode =

# Following this we need to compare which assets are exceeding individual product limits. 
# and how much many need their exchange position limit need increase.
# Compare between both USD Values of "pivot_table" dataframe and "pivot_table_exchange" dataframe.
